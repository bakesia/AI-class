# %% [markdown]
# # **파이토치 시험 나올 부분**
#
# **1-2장**
# - 18p 그림 중요 1-2
# - 19p 머신러닝 딥러닝 설명 틀린거 같음
# - 20p 그림 중요
# - 21p 특성 추출
# - 22p 훈련데이터셋 세팅 중요
# - 24p 학습 종류 중요
# - 27p 배치 개념 중요
# - 스킵
# - 54-55p 다 중요한 개념이라 함
# - 소스코드는 알아서 보삼 크게 안 중요함
# - 85-87p 지표들 중요하다 함
#
# **3장**
#
# - knn 개념
# - 95p 서포트 뭐시기 개념
# - 101p 결정트리등 개념 다
# - 107p 로지스트 회귀
# - 108p 라이클리우드?
# - 112p 컴퓨터매트리스 의미
# - 113p 선형회귀 로지스트회귀 차이
# - 117p 수식 중요
# - 119p k민스는 안하지만 차이점(knn) 지도 비지도 차이
# - 125p 디비스캔 스킵
# - pca 중요
#
# - 143-7p 활성화 함수 역할 중요
# - 149p 과적합
# - 150p
# - 152-3p 경사하강법 3가지, 옵티마이저가 뭐냐
# - 170-71p 중요하다고 함
#
#
# **5.3**
# - 전이학습
#
# ---여기까지 1차 목표---
