# %%
# 라이브러리 임포트
# 세션 변경으로 GPU 설정

import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# 1. 데이터 로드 함수 (CNN과 동일)

def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    loaded = np.dstack(loaded)
    return loaded

def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    filenames = [
        'total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt',
        'body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt',
        'body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt'
    ]
    X = load_group(filenames, filepath)
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

def load_dataset(prefix=''):
    dataset_path = '/content/drive/MyDrive/Colab Notebooks/기계학습프로그래밍/10주/UCI HAR Dataset/'
    trainX, trainy = load_dataset_group('train', dataset_path)
    testX, testy = load_dataset_group('test', dataset_path)

    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)

    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# 2. 데이터 불러오기 및 분할

trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()

X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX, trainy_one_hot, trainy,
    test_size=0.2,
    random_state=100
)

print(X_train.shape, X_val.shape, y_train_one_hot.shape, y_val_one_hot.shape)
# Out:
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-284784650.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)
# (5881, 128, 9) (1471, 128, 9) (5881, 6) (1471, 6)

# %%
# 3. LSTM 모델 정의 (CNN과 동일 구조, Conv → LSTM)

n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

lstm_model = Sequential([
    LSTM(128, input_shape=(n_timesteps, n_features), return_sequences=True),
    Dropout(0.4),

    LSTM(64),
    Dropout(0.3),

    Dense(64, activation='relu'),
    Dense(n_outputs, activation='softmax')
])

lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
lstm_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128, 128)       │        70,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 124,614 (486.77 KB)
#  Trainable params: 124,614 (486.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 4. 학습

lstm_history = lstm_model.fit(
    X_train, y_train_one_hot,
    epochs=30,
    batch_size=64,
    validation_data=(X_val, y_val_one_hot),
    verbose=1
)
# Out:
# Epoch 1/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.4387 - loss: 1.3529 - val_accuracy: 0.6655 - val_loss: 0.7621
# Epoch 2/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6988 - loss: 0.6786 - val_accuracy: 0.5969 - val_loss: 1.0268
# Epoch 3/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7359 - loss: 0.5965 - val_accuracy: 0.8029 - val_loss: 0.4775
# Epoch 4/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8045 - loss: 0.4539 - val_accuracy: 0.8416 - val_loss: 0.4140
# Epoch 5/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8465 - loss: 0.4005 - val_accuracy: 0.8613 - val_loss: 0.3717
# Epoch 6/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9120 - loss: 0.2389 - val_accuracy: 0.9334 - val_loss: 0.1737
# Epoch 7/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9441 - loss: 0.1434 - val_accuracy: 0.9279 - val_loss: 0.1723
# Epoch 8/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9297 - loss: 0.1818 - val_accuracy: 0.9375 - val_loss: 0.1472
# Epoch 9/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9472 - loss: 0.1304 - val_accuracy: 0.9300 - val_loss: 0.1549
# Epoch 10/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9416 - loss: 0.1312 - val_accuracy: 0.9252 - val_loss: 0.1751
# Epoch 11/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9380 - loss: 0.1686 - val_accuracy: 0.9449 - val_loss: 0.1449
# Epoch 12/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9466 - loss: 0.1381 - val_accuracy: 0.9334 - val_loss: 0.1475
# Epoch 13/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9402 - loss: 0.1452 - val_accuracy: 0.9538 - val_loss: 0.1395
# Epoch 14/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9518 - loss: 0.1223 - val_accuracy: 0.9470 - val_loss: 0.1245
# Epoch 15/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9421 - loss: 0.1595 - val_accuracy: 0.9511 - val_loss: 0.1225
# Epoch 16/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9502 - loss: 0.1231 - val_accuracy: 0.9497 - val_loss: 0.1221
# Epoch 17/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9529 - loss: 0.1172 - val_accuracy: 0.9545 - val_loss: 0.1099
# Epoch 18/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9546 - loss: 0.1099 - val_accuracy: 0.9524 - val_loss: 0.1118
# Epoch 19/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9193 - loss: 0.2583 - val_accuracy: 0.9320 - val_loss: 0.1735
# Epoch 20/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9550 - loss: 0.1218 - val_accuracy: 0.9511 - val_loss: 0.1229
# Epoch 21/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9586 - loss: 0.1068 - val_accuracy: 0.9551 - val_loss: 0.1152
# Epoch 22/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9552 - loss: 0.1116 - val_accuracy: 0.9388 - val_loss: 0.1440
# Epoch 23/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9429 - loss: 0.1261 - val_accuracy: 0.9565 - val_loss: 0.1163
# Epoch 24/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9506 - loss: 0.1205 - val_accuracy: 0.9558 - val_loss: 0.1106
# Epoch 25/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9573 - loss: 0.1004 - val_accuracy: 0.9477 - val_loss: 0.1145
# Epoch 26/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9550 - loss: 0.0981 - val_accuracy: 0.9531 - val_loss: 0.1125
# Epoch 27/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9596 - loss: 0.1072 - val_accuracy: 0.9517 - val_loss: 0.1078
# Epoch 28/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9580 - loss: 0.1068 - val_accuracy: 0.9511 - val_loss: 0.1163
# Epoch 29/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9626 - loss: 0.1049 - val_accuracy: 0.9001 - val_loss: 0.1729
# Epoch 30/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9337 - loss: 0.1541 - val_accuracy: 0.9456 - val_loss: 0.1197

# %%
# 5. 평가

loss, acc = lstm_model.evaluate(testX, testy_one_hot, verbose=0)
print(f'Test Accuracy: {acc:.4f}')
# Out:
# Test Accuracy: 0.9101

# %%
# 6. 학습 결과 시각화

loss = lstm_history.history['loss']
val_loss = lstm_history.history['val_loss']
acc = lstm_history.history['accuracy']
val_acc = lstm_history.history['val_accuracy']
epochs = range(1, len(loss) + 1)

# 손실 그래프

plt.figure(figsize=(8, 4))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# 정확도 그래프

plt.figure(figsize=(8, 4))
plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# 7. 예측 및 혼동행렬

pred = lstm_model.predict(testX)
pred = np.argmax(pred, axis=-1)
true = np.argmax(testy_one_hot, axis=-1)

print("✅ Test Accuracy:", accuracy_score(true, pred))
print("\n📊 Classification Report:\n", classification_report(true, pred))

cm = confusion_matrix(true, pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix (LSTM)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# ✅ Test Accuracy: 0.9100780454699695
#
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97       496
#            1       0.94      0.99      0.96       471
#            2       0.92      1.00      0.96       420
#            3       0.88      0.68      0.77       491
#            4       0.76      0.92      0.83       532
#            5       1.00      0.95      0.97       537
#
#     accuracy                           0.91      2947
#    macro avg       0.92      0.91      0.91      2947
# weighted avg       0.92      0.91      0.91      2947
